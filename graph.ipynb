# %% [markdown]
# ### **Load Necessary Libraries**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### **Read Data CSV File**

# %%
url = 'https://drive.google.com/file/d/1zP9kNiw2TEsYl9Dcaq5VPaCJxtP9uaz4/view?usp=sharing'
file_id = url.split('/')[-2]
down_url = 'https://drive.google.com/uc?id=' + file_id
data = pd.read_csv(down_url)
data
# Out:
#       x   2x   3x      x^3     log x  2x^2+3x  3x+2   x^2    1000x
# 0     1    2    3        1  0.000000        5     5      4    1000
# 1     2    4    6        8  0.301030       14     8     16    2000
# 2     3    6    9       27  0.477121       27    11     36    3000
# 3     4    8   12       64  0.602060       44    14     64    4000
# 4     5   10   15      125  0.698970       65    17    100    5000
# ..  ...  ...  ...      ...       ...      ...   ...    ...     ...
# 95   96  192  288   884736  1.982271    18720   290  36864   96000
# 96   97  194  291   912673  1.986772    19109   293  37636   97000
# 97   98  196  294   941192  1.991226    19502   296  38416   98000
# 98   99  198  297   970299  1.995635    19899   299  39204   99000
# 99  100  200  300  1000000  2.000000    20300   302  40000  100000
#
# [100 rows x 9 columns]

# %% [markdown]
# ### **Funtion Y = 2x**

# %%
x = data['x']
y = data['2x']
plt.title('Y = 2x')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### **Funtion Y = 3x**

# %%
x = data['x']
y = data['3x']
plt.title('Y = 3x')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ###**Funtion Y = x^3**

# %%
x = data['x']
y = data['x^3']
plt.title('Y = x^3')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### **Funtion Y = log x**

# %%
x = data['x']
y = data['log x']
plt.title('Y = log x')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### **Function Y = 2x^2+3x**

# %%
x = data['x']
y = data['2x^2+3x']
plt.title('Y = 2x^2+3x')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### **Function Y = 3x+2**

# %%
x = data['x']
y = data['3x+2']
plt.title('Y = 3x+2')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### **Function Y = x^2 v/s 1000x**

# %%
index = 1
x = []
y = []
z = []

for i in range(1, 1500):
  x.insert(i, i)
  y.insert(i, pow(i, 2))
  z.insert(i, 1000 * i)
  

plt.title('Y = x^2 v/s 1000x')
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.plot(x, y)
plt.plot(x, z)
plt.show()

# %% [markdown]
# ### **Describe the region where the two functions meet.**
#
# ---
#     Y = X^2
#     Y = 1000 X
#     X^2 = 1000 X
#     X * X = 1000 X
#     X = 1000 (Point Where the two function will meet)
#
# So the point in 1000.
